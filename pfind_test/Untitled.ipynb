# %%
from S15qkd.g2lib import g2lib

# %%
t_alice, ch_alice = g2lib._data_extractor('alice-fanout_2.dat')
t_bob, ch_bob = g2lib._data_extractor('bob_fanout_2.dat')
len(t_alice)
len(t_bob)
# Out:
# 122880

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
histo = g2lib.delta_loop(t_alice, t_bob, bins=10e6, bin_width=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(histo)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t_alice[0] * 1e-9, t_bob[0] * 1e-9
# Out:
# (0.0013165586250000001, 0.001511336375)
